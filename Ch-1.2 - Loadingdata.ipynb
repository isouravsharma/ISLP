# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("../data/Auto.csv")
data
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 0    18.0          8         307.0         130    3504          12.0    70
# 1    15.0          8         350.0         165    3693          11.5    70
# 2    18.0          8         318.0         150    3436          11.0    70
# 3    16.0          8         304.0         150    3433          12.0    70
# 4    17.0          8         302.0         140    3449          10.5    70
# ..    ...        ...           ...         ...     ...           ...   ...
# 387  27.0          4         140.0          86    2790          15.6    82
# 388  44.0          4          97.0          52    2130          24.6    82
# 389  32.0          4         135.0          84    2295          11.6    82
# 390  28.0          4         120.0          79    2625          18.6    82
# 391  31.0          4         119.0          82    2720          19.4    82
#
#      origin                       name
# ...

# %%
data['horsepower']
# Out:
# 0      130
# 1      165
# 2      150
# 3      150
# 4      140
#       ...
# 387     86
# 388     52
# 389     84
# 390     79
# 391     82
# Name: horsepower, Length: 392, dtype: int64

# %%
np.unique(data['horsepower'])
# Out:
# array([ 46,  48,  49,  52,  53,  54,  58,  60,  61,  62,  63,  64,  65,
#         66,  67,  68,  69,  70,  71,  72,  74,  75,  76,  77,  78,  79,
#         80,  81,  82,  83,  84,  85,  86,  87,  88,  89,  90,  91,  92,
#         93,  94,  95,  96,  97,  98, 100, 102, 103, 105, 107, 108, 110,
#        112, 113, 115, 116, 120, 122, 125, 129, 130, 132, 133, 135, 137,
#        138, 139, 140, 142, 145, 148, 149, 150, 152, 153, 155, 158, 160,
#        165, 167, 170, 175, 180, 190, 193, 198, 200, 208, 210, 215, 220,
#        225, 230])

# %%
np.sum(data['horsepower'])
# Out:
# 40952

# %%
data.shape
# Out:
# (392, 9)

# %%
# Basic selction of rows and column

Auto = data
Auto.columns
# Out:
# Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'year', 'origin', 'name'],
#       dtype='object')

# %%
# Accessing the rows
Auto[:3]
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 0  18.0          8         307.0         130    3504          12.0    70
# 1  15.0          8         350.0         165    3693          11.5    70
# 2  18.0          8         318.0         150    3436          11.0    70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite

# %%
idx_80 = Auto['year']> 80
Auto[idx_80]
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 334  27.2          4         135.0          84    2490          15.7    81
# 335  26.6          4         151.0          84    2635          16.4    81
# 336  25.8          4         156.0          92    2620          14.4    81
# 337  23.5          6         173.0         110    2725          12.6    81
# 338  30.0          4         135.0          84    2385          12.9    81
# 339  39.1          4          79.0          58    1755          16.9    81
# 340  39.0          4          86.0          64    1875          16.4    81
# 341  35.1          4          81.0          60    1760          16.1    81
# 342  32.3          4          97.0          67    2065          17.8    81
# 343  37.0          4          85.0          65    1975          19.4    81
# 344  37.7          4          89.0          62    2050          17.3    81
# ...

# %%
Auto[['mpg','horsepower']]
# Out:
#       mpg  horsepower
# 0    18.0         130
# 1    15.0         165
# 2    18.0         150
# 3    16.0         150
# 4    17.0         140
# ..    ...         ...
# 387  27.0          86
# 388  44.0          52
# 389  32.0          84
# 390  28.0          79
# 391  31.0          82
#
# [392 rows x 2 columns]

# %%
# Index 
Auto.index
# Out:
# RangeIndex(start=0, stop=392, step=1)

# %%
Auto_re = Auto.set_index('name')
Auto_re
# Out:
#                             mpg  cylinders  displacement  horsepower  weight  \
# name
# chevrolet chevelle malibu  18.0          8         307.0         130    3504
# buick skylark 320          15.0          8         350.0         165    3693
# plymouth satellite         18.0          8         318.0         150    3436
# amc rebel sst              16.0          8         304.0         150    3433
# ford torino                17.0          8         302.0         140    3449
# ...                         ...        ...           ...         ...     ...
# ford mustang gl            27.0          4         140.0          86    2790
# vw pickup                  44.0          4          97.0          52    2130
# dodge rampage              32.0          4         135.0          84    2295
# ford ranger                28.0          4         120.0          79    2625
# chevy s-10                 31.0          4         119.0          82    2720
#
# ...

# %%
Auto_re.columns
# Out:
# Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'year', 'origin'],
#       dtype='object')

# %%
Auto_re.loc['vw pickup']
# Out:
# mpg               44.0
# cylinders          4.0
# displacement      97.0
# horsepower        52.0
# weight          2130.0
# acceleration      24.6
# year              82.0
# origin             2.0
# Name: vw pickup, dtype: float64

# %%
#.iloc method

Auto_re.iloc[[3,4]]
# Out:
#                 mpg  cylinders  displacement  horsepower  weight  \
# name
# amc rebel sst  16.0          8         304.0         150    3433
# ford torino    17.0          8         302.0         140    3449
#
#                acceleration  year  origin
# name
# amc rebel sst          12.0    70       1
# ford torino            10.5    70       1

# %%
Auto_re.iloc[:,[0,3,5]]
# Out:
#                             mpg  horsepower  acceleration
# name
# chevrolet chevelle malibu  18.0         130          12.0
# buick skylark 320          15.0         165          11.5
# plymouth satellite         18.0         150          11.0
# amc rebel sst              16.0         150          12.0
# ford torino                17.0         140          10.5
# ...                         ...         ...           ...
# ford mustang gl            27.0          86          15.6
# vw pickup                  44.0          52          24.6
# dodge rampage              32.0          84          11.6
# ford ranger                28.0          79          18.6
# chevy s-10                 31.0          82          19.4
#
# [392 rows x 3 columns]

# %%
Auto_re.iloc[[3,4],[0,3,4]]
# Out:
#                 mpg  horsepower  weight
# name
# amc rebel sst  16.0         150    3433
# ford torino    17.0         140    3449

# %%
Auto_re.loc[lambda df: df['year']> 80, ['weight', 'origin']]
# Out:
#                                    weight  origin
# name
# plymouth reliant                     2490       1
# buick skylark                        2635       1
# dodge aries wagon (sw)               2620       1
# chevrolet citation                   2725       1
# plymouth reliant                     2385       1
# toyota starlet                       1755       3
# plymouth champ                       1875       1
# honda civic 1300                     1760       3
# subaru                               2065       3
# datsun 210 mpg                       1975       3
# toyota tercel                        2050       3
# mazda glc 4                          1985       3
# plymouth horizon 4                   2215       1
# ford escort 4w                       2045       1
# ford escort 2h                       2380       1
# volkswagen jetta                     2190       2
# honda prelude                        2210       3
# toyota corolla                       2350       3
# ...

# %%
Auto_re.loc[lambda df: (df['year']> 80) & (df['mpg']> 30), ['weight', 'origin']]
# Out:
#                                    weight  origin
# name
# toyota starlet                       1755       3
# plymouth champ                       1875       1
# honda civic 1300                     1760       3
# subaru                               2065       3
# datsun 210 mpg                       1975       3
# toyota tercel                        2050       3
# mazda glc 4                          1985       3
# plymouth horizon 4                   2215       1
# ford escort 4w                       2045       1
# volkswagen jetta                     2190       2
# honda prelude                        2210       3
# toyota corolla                       2350       3
# datsun 200sx                         2615       3
# mazda 626                            2635       3
# volvo diesel                         3160       2
# chevrolet cavalier 2-door            2395       1
# pontiac j2000 se hatchback           2575       1
# volkswagen rabbit l                  1980       2
# ...

# %%
Auto_re.loc[lambda df: (df['displacement']> 300)&(df.index.str.contains('ford'))|(df.index.str.contains('datsun'))]
# Out:
#                            mpg  cylinders  displacement  horsepower  weight  \
# name
# ford torino               17.0          8         302.0         140    3449
# ford galaxie 500          15.0          8         429.0         198    4341
# datsun pl510              27.0          4          97.0          88    2130
# ford f250                 10.0          8         360.0         215    4615
# datsun pl510              27.0          4          97.0          88    2130
# ford galaxie 500          14.0          8         351.0         153    4154
# ford country squire (sw)  13.0          8         400.0         170    4746
# datsun 1200               35.0          4          72.0          69    1613
# ford galaxie 500          14.0          8         351.0         153    4129
# ford gran torino (sw)     13.0          8         302.0         140    4294
# datsun 510 (sw)           28.0          4          97.0          92    2288
# ...

# %%
# for loop 

total = 0

for value in [3,5,2,2]:
    total += value
    print(f"Value of total is: {total}")

print(f"Final Value of total is: {total}")
# Out:
# Value of total is: 3
# Value of total is: 8
# Value of total is: 10
# Value of total is: 12
# Final Value of total is: 12

# %%
# nested for loop

total = 0 

for value in [3,4,5]:
    for val in [1,2,3]:
        total += value * val
        print(f" Value is {value} and val is {val} total is {total}")
# Out:
#  Value is 3 and val is 1 total is 3
#  Value is 3 and val is 2 total is 9
#  Value is 3 and val is 3 total is 18
#  Value is 4 and val is 1 total is 22
#  Value is 4 and val is 2 total is 30
#  Value is 4 and val is 3 total is 42
#  Value is 5 and val is 1 total is 47
#  Value is 5 and val is 2 total is 57
#  Value is 5 and val is 3 total is 72

# %%
# zip function: 
total = 0 

for val1, val2 in zip([1,2,3],[.2,.3,.5]):
    total+= val1*val2
    print(f"value of val1 is {val1}, val2 is {val2} and total is {total}")
# Out:
# value of val1 is 1, val2 is 0.2 and total is 0.2
# value of val1 is 2, val2 is 0.3 and total is 0.8
# value of val1 is 3, val2 is 0.5 and total is 2.3

# %%
# String formatting

rng = np.random.default_rng(seed = 13)
A = rng.standard_normal((125,5))
M = rng.choice([0, np.nan], p = [0.8,0.2], size = A.shape)
A +=M
D = pd.DataFrame(A, columns=['food','bar','pickle','popcorn','pizza'])
D
# Out:
#          food       bar    pickle   popcorn     pizza
# 0    1.826757 -3.078332  0.958064  0.069637  1.318250
# 1    0.385629  1.827259  0.031744       NaN  0.580485
# 2    0.432107 -0.356839 -0.247304  0.719441  0.704316
# 3   -0.493934 -0.367714 -1.806790  1.679207 -0.224291
# 4    1.337277  0.417466  1.943963       NaN  0.318298
# ..        ...       ...       ...       ...       ...
# 120  0.034942  0.234941  0.785903  0.720748  0.335644
# 121       NaN  0.318494 -0.452229       NaN  0.912331
# 122 -0.650836 -1.183311  0.098240 -1.919744 -0.053409
# 123  0.460277 -0.409935  0.248711  2.167281  1.435541
# 124  0.942517       NaN -0.509514 -0.132210 -0.279424
#
# [125 rows x 5 columns]

# %%
# find the missing values in food column 

for value in D:
    # print(value)
    print(f"Missing value in {value} is {round((pd.isna(D[value]).value_counts().iloc[1])/len(D[value]),2)}%")
# Out:
# Missing value in food is 0.18%
# Missing value in bar is 0.17%
# Missing value in pickle is 0.14%
# Missing value in popcorn is 0.24%
# Missing value in pizza is 0.15%

# %%
fig, ax = plt.subplots(figsize=(5,3), nrows=1 , ncols= 2)
ax[0].plot(Auto['horsepower'], Auto['mpg'], marker = 'o')
ax[1].scatter(Auto['horsepower'], Auto['mpg'], marker = 'o');

# %%
# fig, ax = plt.subplots(figsize=(5,3))
Auto.boxplot('mpg', by='cylinders');

# %%
Auto.hist('mpg', bins = 12, color= 'red')
# Out:
# array([[<Axes: title={'center': 'mpg'}>]], dtype=object)

# %%
pd.plotting.scatter_matrix(Auto);

# %%
Auto.describe()
# Out:
#               mpg   cylinders  displacement  horsepower       weight  \
# count  392.000000  392.000000    392.000000  392.000000   392.000000
# mean    23.445918    5.471939    194.411990  104.469388  2977.584184
# std      7.805007    1.705783    104.644004   38.491160   849.402560
# min      9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%     17.000000    4.000000    105.000000   75.000000  2225.250000
# 50%     22.750000    4.000000    151.000000   93.500000  2803.500000
# 75%     29.000000    8.000000    275.750000  126.000000  3614.750000
# max     46.600000    8.000000    455.000000  230.000000  5140.000000
#
#        acceleration        year      origin
# count    392.000000  392.000000  392.000000
# mean      15.541327   75.979592    1.576531
# std        2.758864    3.683737    0.805518
# min        8.000000   70.000000    1.000000
# 25%       13.775000   73.000000    1.000000
# 50%       15.500000   76.000000    1.000000
# ...
